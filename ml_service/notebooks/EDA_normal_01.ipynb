# %% [markdown]
# ### EXPLANATORY DATA ANALYSIS OF NORMAL TRANSCIENT DATA

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import openpyxl as xl
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# Data Path
data_path = os.path.join(os.path.dirname(os.getcwd()), "data", "raw")
file_path = os.path.join(data_path, "normal_dataset.csv")
#Load the dataset
df = pd.read_csv(file_path)
# Display the first few rows of the dataset
df.head(10)

# %%
# Get the summary statistics of the dataset
df.describe()

# %%
# Print the column names
df.columns

# %%
# Get the shape of the dataset
df.shape

# %%
# Check for duplicates
print(df.columns[df.columns.duplicated()].tolist())

# %%
# Check for the data types of each column
df.dtypes
